# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preparing data

# %%
# !scp '/content/drive/MyDrive/PCOS/Image Classification/Dataset.zip' '/content/Dataset.zip'

# !unzip '/content/Dataset.zip' -d '/content/'
# Out:
# Archive:  /content/Dataset.zip
#    creating: /content/Dataset/Test/
#    creating: /content/Dataset/Test/NORMAL/
#   inflating: /content/Dataset/Test/NORMAL/793.jpg
#   inflating: /content/Dataset/Test/NORMAL/794.jpg
#   inflating: /content/Dataset/Test/NORMAL/795.jpg
#   inflating: /content/Dataset/Test/NORMAL/796.jpg
#   inflating: /content/Dataset/Test/NORMAL/797.jpg
#   inflating: /content/Dataset/Test/NORMAL/798.jpg
#   inflating: /content/Dataset/Test/NORMAL/799.jpg
#   inflating: /content/Dataset/Test/NORMAL/8.jpg
#   inflating: /content/Dataset/Test/NORMAL/80.jpg
#   inflating: /content/Dataset/Test/NORMAL/800.jpg
#   inflating: /content/Dataset/Test/NORMAL/801.jpg
#   inflating: /content/Dataset/Test/NORMAL/802.jpg
#   inflating: /content/Dataset/Test/NORMAL/803.jpg
#   inflating: /content/Dataset/Test/NORMAL/804.jpg
#   inflating: /content/Dataset/Test/NORMAL/805.jpg
#   inflating: /content/Dataset/Test/NORMAL/806.jpg
#   inflating: /content/Dataset/Test/NORMAL/807.jpg
# ...

# %% [markdown]
# # Installing modules

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.5/792.5 kB 15.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# # Training the model

# %%
import os
from ultralytics import YOLO

# Load YOLO model
model = YOLO('yolov8n-cls.pt')

# Train the model
results = model.train(data='/content/Dataset/', epochs=50)
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Copying the results

# %%
# !scp -r /content/runs '/content/drive/MyDrive/PCOS/Image Classification'

# %% [markdown]
# # Saving our model

# %%
import torch

# Assuming 'model' is your trained PyTorch model
# Save the model's state dictionary
torch.save(model.state_dict(), '/content/drive/MyDrive/PCOS/Image Classification/trained_model.pth')

# Optionally, save the entire model (including architecture and state)
# torch.save(model, '/content/drive/MyDrive/PCOS/Image Classification/full_trained_model.pth')

# %% [markdown]
# # Loading saved model

# %%
# # Load the model's state dictionary
# model = YourModelClass()
# model.load_state_dict(torch.load('/content/drive/MyDrive/PCOS/Image Classification/trained_model.pth'))
# model.eval()  # Set the model to evaluation mode

# # If you saved the entire model, load it like this:
# # model = torch.load('/content/drive/MyDrive/PCOS/Image Classification/full_trained_model.pth')
